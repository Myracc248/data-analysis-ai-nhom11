# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tesco-grocery-uk.csv')

# %%
df = df.rename(columns={
    "sku": "Product_ID",
    "name": "Product_Name",
    "category_1": "Category",
    "brand": "Brand",
    "original_price": "Original_Price",
    "price": "Discount_Price"
})

# %%
# Lưu dữ liệu đã chuẩn hóa vào file csv
df.to_csv("tesco-grocery-uk.csv", index=False)

print("Đã cập nhật file CSV!")

# Kiểm tra
print(df.head())
print(df.columns)
# Out:
# Đã cập nhật file CSV!
#                                         Product_Name  Product_ID       tpnc  \
# 0                     Malibu Original Coconut Rum 1L   254870847  254870847
# 1   Walkers Wotsits Cheese Multipack Crisps 12x16.5g   261495181  261495181
# 2  Listerine Total Care Intense Taste Classic Mou...   262720979  262720979
# 3     Walkers Roast Chicken Multipack Crisps 6 x 25g   321658606  321658606
# 4      Walkers Smokey Bacon Multipack Crisps 6 x 25g   321769965  321769965
#
#        tpnb           gtin         gtin13 Discount_Price unit_price  \
# 0  57420176  8410024710618  8410024710618           22.5       22.5
# 1  60266089  5000328288529  5000328288529           2.99       15.1
# 2  61463009  5010123730222  5010123730222           5.25       10.5
# 3  96874748  5000328034584  5000328034584            2.2      14.67
# 4  96884385  5000328037721  5000328037721            2.2      14.67
#
#   unit_of_measure currency  ... healthmark  lower_age_limit nappies  \
# 0           litre      GBP  ...         \N         18 Years      \N
# 1              kg      GBP  ...         \N               \N      \N
# 2           litre      GBP  ...         \N               \N      \N
# 3              kg      GBP  ...         \N               \N      \N
# 4              kg      GBP  ...         \N               \N      \N
#
#   net_contents                      number_of_uses safety_warning  \
# 0           1l                                  \N             \N
# 1  12 x 16.5g   Each inner pack contains 1 serving             \N
# 2       500ml                                   \N             \N
# 3     6 x 25g   Each inner pack contains 1 serving             \N
# 4     6 x 25g   Each inner pack contains 1 serving             \N
#
#   upper_age_limit       _version         _imported_at Original_Price
# 0              \N  1778705311983  2026-05-13 20:48:31           22.5
# 1              \N  1778705311983  2026-05-13 20:48:31           2.99
# 2              \N  1778705311983  2026-05-13 20:48:31           5.25
# 3              \N  1778705311983  2026-05-13 20:48:31            2.2
# 4              \N  1778705311983  2026-05-13 20:48:31            2.2
#
# [5 rows x 83 columns]
# Index(['Product_Name', 'Product_ID', 'tpnc', 'tpnb', 'gtin', 'gtin13',
#        'Discount_Price', 'unit_price', 'unit_of_measure', 'currency',
#        'availability', 'is_for_sale', 'base_product_id', 'shelfLife',
#        'foodIcons', 'restrictions', 'manufacturer', 'manufacturer_address',
#        'images', 'description', 'product_url', 'Brand', 'avg_rating',
#        'reviews_count', 'uniq_id', 'pack_size', 'alcohol_units', 'abv',
#        'Category', 'category_2', 'category_3', 'breadcrumbs', 'ingredients',
#        'nutrition', 'specifications', 'features', 'warnings', 'storage',
#        'other_information', 'allergens', 'preparation_and_usage',
#        'brand_marketing', 'product_marketing', 'origin_information',
#        'legal_labelling', 'nutritional_claims', 'directions',
#        'preparation_guidelines', 'cooking_instructions', 'clothing_info',
#        'product_dimensions', 'recycling_info', 'manufacturer_marketing',
#        'other_nutrition_information', 'pack_size_info', 'is_new',
#        'product_type', 'super_department', 'department', 'aisle',
#        'distributor_address', 'importer_address', 'multi_pack_details',
#        'additives', 'box_contents', 'components', 'dosage', 'drained_weight',
#        'energy_efficiency', 'freezing_instructions', 'guideline_daily_amount',
#        'hazard_info', 'health_claims', 'healthmark', 'lower_age_limit',
#        'nappies', 'net_contents', 'number_of_uses', 'safety_warning',
#        'upper_age_limit', '_version', '_imported_at', 'Original_Price'],
#       dtype='object')
