# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('vietnamese_tiki_products_backpacks_suitcases.csv')

# %%
df = df.rename(columns={
    "id": "Product_ID",
    "name": "Product_Name",
    "category": "Category",
    "brand": "Brand",
    "original_price": "Original_Price",
    "price": "Discount_Price"
})
# Out:
# Index(['Product_ID', 'Product_Name', 'description', 'Original_Price',
#        'Discount_Price', 'fulfillment_type', 'Brand', 'review_count',
#        'rating_average', 'favourite_count', 'pay_later', 'current_seller',
#        'date_created', 'number_of_images', 'vnd_cashback', 'has_video',
#        'Category', 'quantity_sold'],
#       dtype='object')

# %%
# Lưu dữ liệu đã chuẩn hóa vào file csv
df.to_csv("vietnamese_tiki_products_backpacks_suitcases.csv", index=False)

print("Đã cập nhật file CSV!")

# Kiểm tra
print(df.head())
print(df.columns)
# Out:
# Đã cập nhật file CSV!
#    Product_ID                                       Product_Name  \
# 0   179731375  Balo nữ da dầy thời trang unisex màu sắc tươi ...
# 1   249221065            Ví da đựng thẻ ngân hàng (7 màu) - 9205
# 2   102862196   Balo nam nữ thời trang họa tiết bò sữa kiểu m...
# 3   115740385  Vải nhũ bóng simili chống thấm may túi ví balo...
# 4   102862375   Combo balo vừa a4 và túi tote thời trang kiểu...
#
#                                          description  Original_Price  \
# 0    Balo nữ da dầy thời trang unisex màu sắc tươ...           14250
# 1                                                ...           10260
# 2         Balo họa tiết bò sữa thời trang cho nam...           19999
# 3         _ Vải nhũ bóng siêu xinh và cực kì xịn ...           30000
# 4         BALO THỜI TRANG - BALO ĐẸP – BALO HỌC S...           29000
#
#    Discount_Price fulfillment_type Brand  review_count  rating_average  \
# 0           14250         dropship   OEM             0             0.0
# 1           10260         dropship   OEM             0             0.0
# 2           19999         dropship   OEM             0             0.0
# 3           30000         dropship   OEM             0             0.0
# 4           29000         dropship   OEM             0             0.0
#
#    favourite_count  pay_later          current_seller  date_created  \
# 0                0      False           Thiên Ân Balo           488
# 1                0      False      SHOP THỜI TRANG 2N           166
# 2                0      False  Xưởng may balo Đà Nẵng           831
# 3                0      False               BB Outlet           775
# 4                0      False  Xưởng may balo Đà Nẵng           831
#
#    number_of_images  vnd_cashback  has_video Category  quantity_sold
# 0                10             0      False  Balo nữ              0
# 1                 2             0      False     Root              0
# 2                 5             0      False     Root              0
# 3                 4             0      False     Root              0
# 4                 5             0      False     Root              0
# Index(['Product_ID', 'Product_Name', 'description', 'Original_Price',
#        'Discount_Price', 'fulfillment_type', 'Brand', 'review_count',
#        'rating_average', 'favourite_count', 'pay_later', 'current_seller',
#        'date_created', 'number_of_images', 'vnd_cashback', 'has_video',
#        'Category', 'quantity_sold'],
#       dtype='object')
